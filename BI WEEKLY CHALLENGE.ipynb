# %%
def age_print(age,name,today):

    """Python function that prints user name and age
     with given inputs
     
     Keywords arguments:
     age ---  The age of the user
     name --- The name of the user
     today --- The current year
     
     
    """
    
    try:
        
        if age>0:  #this checks if the age is greater than zero

            birth = today - age   #variable birth declaration
            
            decade_ago = today - 10 #variable decade_ago substacts 10 years from the current year
            
            decade_ago_age = age - 10 # variable  decade_ago_age calculates the age of the user in the past 10 year
            
            print(f"Hello {name} you are {age} years old")
            
            print(f"Your year of birth is {birth}")
            
            print(f"As you are {age} years old,you are an adult")
            
            print(f"In {decade_ago} you were {decade_ago_age} years old ")
            
            for year in range(50):    # the loop iterates through 50 years

                future_year = today + year # calculates the future year 

                age = age + 1       # calculate the new ages for each future year

                print(f"In {future_year} you'll be {age} years old ") 

        elif age < 0:

            print("Please enter correct age") #prompt the user to enter a correct age

    except:

        print("Something went wrong")

# %%
age_print(22,'AYO',2020)
# Out:
# Hello AYO you are 22 years old
# Your year of birth is 1998
# As you are 22 years old,you are an adult
# In 2010 you were 12 years old
# In 2020 you'll be 23 years old
# In 2021 you'll be 24 years old
# In 2022 you'll be 25 years old
# In 2023 you'll be 26 years old
# In 2024 you'll be 27 years old
# In 2025 you'll be 28 years old
# In 2026 you'll be 29 years old
# In 2027 you'll be 30 years old
# In 2028 you'll be 31 years old
# In 2029 you'll be 32 years old
# In 2030 you'll be 33 years old
# In 2031 you'll be 34 years old
# In 2032 you'll be 35 years old
# In 2033 you'll be 36 years old
# In 2034 you'll be 37 years old
# In 2035 you'll be 38 years old
# In 2036 you'll be 39 years old
# In 2037 you'll be 40 years old
# In 2038 you'll be 41 years old
# In 2039 you'll be 42 years old
# In 2040 you'll be 43 years old
# In 2041 you'll be 44 years old
# In 2042 you'll be 45 years old
# In 2043 you'll be 46 years old
# In 2044 you'll be 47 years old
# In 2045 you'll be 48 years old
# In 2046 you'll be 49 years old
# In 2047 you'll be 50 years old
# In 2048 you'll be 51 years old
# In 2049 you'll be 52 years old
# In 2050 you'll be 53 years old
# In 2051 you'll be 54 years old
# In 2052 you'll be 55 years old
# In 2053 you'll be 56 years old
# In 2054 you'll be 57 years old
# In 2055 you'll be 58 years old
# In 2056 you'll be 59 years old
# In 2057 you'll be 60 years old
# In 2058 you'll be 61 years old
# In 2059 you'll be 62 years old
# In 2060 you'll be 63 years old
# In 2061 you'll be 64 years old
# In 2062 you'll be 65 years old
# In 2063 you'll be 66 years old
# In 2064 you'll be 67 years old
# In 2065 you'll be 68 years old
# In 2066 you'll be 69 years old
# In 2067 you'll be 70 years old
# In 2068 you'll be 71 years old
# In 2069 you'll be 72 years old
